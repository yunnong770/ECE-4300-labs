# %% [markdown]
#  # Lab 09:  Transfer Learning with a Pre-Trained Deep Neural Network
#
# As we discussed earlier, state-of-the-art neural networks involve millions of parameters that are prohibitively difficult to train from scratch.  In this lab, we will illustrate a powerful technique called *transfer learning*, where we start with a large pre-trained network and then re-train only the final layers to adapt it to a new task.  The method is also called *fine-tuning* and can produce excellent results on very small datasets with very little computational time.
#
# This lab is based partially on this
# [excellent blog](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), althought the details there are for Keras, not PyTorch.  In performing this lab, you will learn to:
# * Build a custom image dataset
# * Fine tune the final layers of an existing deep neural network for a new classification task.
#
# You may run the lab on a CPU machine (like a laptop) or a GPU.  See the [notes](../GCP/readme.md) on setting up a GPU instance on Google Cloud Platform.  The GPU training is much faster (< 1 minute).  But, even the CPU training time should be < 20 minutes.

# %% [markdown]
# ## Create a Dataset
#
# In this lab, we will train a network to discriminate between two classes:  `cars` and `bicycles`.  One could imagine that this type of network could be useful in vehicle vision systems.   The first task is to build a dataset.  For this, please follow the directions in [demo_cnn_flickr](../Demos/demo_cnn_flickr.ipynb)
#
# TODO:  Create training and test directories with:
# * 1000 training images of cars
# * 1000 training images of bicylces
# * 300 test images of cars
# * 300 test images of bicycles
# * The images don't need to be the same size.
#
# The images should be organized in the following directory structure:
#
#     ./train
#         /car
#            car_0000.jpg
#            car_0001.jpg
#            ...
#            car_0999.jpg
#         /bicycle
#            bicycle_0000.jpg
#            bicycle_0001.jpg
#            ...
#            bicycle_0999.jpg
#     ./test
#         /car
#            car_0000.jpg
#            car_0001.jpg
#            ...
#            car_0299.jpg
#         /bicycle
#            bicycle_0000.jpg
#            bicycle_0001.jpg
#            ...
#            bicycle_0299.jpg

# %%
import flickrapi
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import skimage.io
import skimage.transform
import urllib
import requests
from io import BytesIO

# %%
api_key = '9a8b5cc0261a35dee23ba75b8ed7172b'
api_secret = 'ca5feced4370a445'

flickr = flickrapi.FlickrAPI(api_key, api_secret)
cars = flickr.walk(text = 'cars', tag_mode = 'all', tags = 'cars', extras = 'url_c', sort = 'relevance', per_page = 500)
bicycles = flickr.walk(text = 'bicycles', tag_mode = 'all', tags = 'bicycles', extras = 'url_c', sort = 'relevance', per_page = 500)
import os

# declare directory names
train_dir = 'train'
test_dir = 'test'


# make a directories for the training and testing images
for root_dir in [train_dir, test_dir]:
    dir_path1 = root_dir + '/'+'cars'
    dir_path2 = root_dir + '/'+'bicycles'

    # check if data exists
    if not os.path.isdir(root_dir):
        os.mkdir(root_dir)
    if not os.path.isdir(dir_path1):
        os.mkdir(dir_path1)
        print("Making directory %s" % dir_path1)
    else:
        print("Will store %s images in directory %s" %(root_dir,dir_path1))
    if not os.path.isdir(dir_path2):
        os.mkdir(dir_path2)
        print("Making directory %s" % dir_path2)
    else:
        print("Will store %s images in directory %s" %(root_dir,dir_path2))
# Out:
# Will store train images in directory train/cars
# Will store train images in directory train/bicycles
# Will store test images in directory test/cars
# Will store test images in directory test/bicycles

# %% [markdown]
# Now we'll select the image dimensions for our neural network.  They need not be the same as those of the downloaded images, or even the 224x224 size that the network was optimized for, but they should be small enough to work on your machine without taking forever.  If you have a CPU machine, a good choice is 64 x 64. But if you have a GPU image, then you can use a larger image size, like 150 x 150.

# %%
nrow = 64
ncol = 64

# %%
import warnings
from random import seed
from random import random
    
ntrain = 1000 # number of training images to download
ntest = 300 # number of testing images to download

# download images, first train then test
seed(1) # make repeatable
pic_classes = [bicycles,cars]
for pic_class in pic_classes:
    itrain = 0 # initialize counter
    itest = 0 # initialize counter
    if pic_class == bicycles:
        image_dir = 'bicycles'
    elif pic_class == cars:
        image_dir = 'cars'
    for photo in pic_class:
        url=photo.get('url_c')
        if not (url is None):

            # Create a file from the URL
            # This may only work in Python3
            response = requests.get(url)
            file = BytesIO(response.content)

            # Read image from file
            im = skimage.io.imread(file)

            # Resize images
            im1 = skimage.transform.resize(im,(nrow,ncol),mode='constant')

            # Convert to uint8, suppress the warning about the precision loss
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                im2 = skimage.img_as_ubyte(im1)

                  # Set the directory randomly 
            #if (random()< ntrain/(ntrain+ntest)):
            if (random()< (ntrain-itrain)/(ntrain-itrain + ntest-itest + 1e-15)):
                if (itrain<ntrain):
                    dir_path = train_dir + '/' + image_dir
                    i = itrain
                    itrain = itrain + 1
                elif (itest<ntest):
                    dir_path = test_dir + '/' + image_dir
                    i = itest
                    itest = itest + 1
                else:
                    break
            else:
                if (itest<ntest):
                    dir_path = test_dir + '/' + image_dir
                    i = itest
                    itest = itest + 1
                elif (itrain<ntrain):
                    dir_path = train_dir + '/' + image_dir
                    i = itrain
                    itrain = itrain + 1
                else:
                    break            
            # Save the image
            local_name = '{0:s}/{1:s}_{2:04d}.jpg'.format(dir_path,image_dir,i)  
            skimage.io.imsave(local_name, im2)      
            print(local_name)
# Out:
# train/bicycles/bicycles_0000.jpg
# test/bicycles/bicycles_0000.jpg
# train/bicycles/bicycles_0001.jpg
# train/bicycles/bicycles_0002.jpg
# train/bicycles/bicycles_0003.jpg
# train/bicycles/bicycles_0004.jpg
# train/bicycles/bicycles_0005.jpg
# test/bicycles/bicycles_0001.jpg
# train/bicycles/bicycles_0006.jpg
# train/bicycles/bicycles_0007.jpg
# test/bicycles/bicycles_0002.jpg
# train/bicycles/bicycles_0008.jpg
# train/bicycles/bicycles_0009.jpg
# train/bicycles/bicycles_0010.jpg
# train/bicycles/bicycles_0011.jpg
# train/bicycles/bicycles_0012.jpg
# train/bicycles/bicycles_0013.jpg
# test/bicycles/bicycles_0003.jpg
# test/bicycles/bicycles_0004.jpg
# train/bicycles/bicycles_0014.jpg
# train/bicycles/bicycles_0015.jpg
# train/bicycles/bicycles_0016.jpg
# test/bicycles/bicycles_0005.jpg
# train/bicycles/bicycles_0017.jpg
# train/bicycles/bicycles_0018.jpg
# train/bicycles/bicycles_0019.jpg
# train/bicycles/bicycles_0020.jpg
# train/bicycles/bicycles_0021.jpg
# train/bicycles/bicycles_0022.jpg
# train/bicycles/bicycles_0023.jpg
# train/bicycles/bicycles_0024.jpg
# train/bicycles/bicycles_0025.jpg
# train/bicycles/bicycles_0026.jpg
# train/bicycles/bicycles_0027.jpg
# train/bicycles/bicycles_0028.jpg
# train/bicycles/bicycles_0029.jpg
# test/bicycles/bicycles_0006.jpg
# train/bicycles/bicycles_0030.jpg
# train/bicycles/bicycles_0031.jpg
# train/bicycles/bicycles_0032.jpg
# test/bicycles/bicycles_0007.jpg
# test/bicycles/bicycles_0008.jpg
# train/bicycles/bicycles_0033.jpg
# train/bicycles/bicycles_0034.jpg
# train/bicycles/bicycles_0035.jpg
# train/bicycles/bicycles_0036.jpg
# test/bicycles/bicycles_0009.jpg
# train/bicycles/bicycles_0037.jpg
# test/bicycles/bicycles_0010.jpg
# train/bicycles/bicycles_0038.jpg
# train/bicycles/bicycles_0039.jpg
# train/bicycles/bicycles_0040.jpg
# test/bicycles/bicycles_0011.jpg
# test/bicycles/bicycles_0012.jpg
# train/bicycles/bicycles_0041.jpg
# train/bicycles/bicycles_0042.jpg
# train/bicycles/bicycles_0043.jpg
# train/bicycles/bicycles_0044.jpg
# test/bicycles/bicycles_0013.jpg
# train/bicycles/bicycles_0045.jpg
# train/bicycles/bicycles_0046.jpg
# train/bicycles/bicycles_0047.jpg
# train/bicycles/bicycles_0048.jpg
# train/bicycles/bicycles_0049.jpg
# train/bicycles/bicycles_0050.jpg
# train/bicycles/bicycles_0051.jpg
# train/bicycles/bicycles_0052.jpg
# test/bicycles/bicycles_0014.jpg
# train/bicycles/bicycles_0053.jpg
# train/bicycles/bicycles_0054.jpg
# train/bicycles/bicycles_0055.jpg
# train/bicycles/bicycles_0056.jpg
# train/bicycles/bicycles_0057.jpg
# train/bicycles/bicycles_0058.jpg
# test/bicycles/bicycles_0015.jpg
# train/bicycles/bicycles_0059.jpg
# train/bicycles/bicycles_0060.jpg
# train/bicycles/bicycles_0061.jpg
# train/bicycles/bicycles_0062.jpg
# test/bicycles/bicycles_0016.jpg
# test/bicycles/bicycles_0017.jpg
# train/bicycles/bicycles_0063.jpg
# test/bicycles/bicycles_0018.jpg
# train/bicycles/bicycles_0064.jpg
# train/bicycles/bicycles_0065.jpg
# test/bicycles/bicycles_0019.jpg
# train/bicycles/bicycles_0066.jpg
# train/bicycles/bicycles_0067.jpg
# train/bicycles/bicycles_0068.jpg
# train/bicycles/bicycles_0069.jpg
# test/bicycles/bicycles_0020.jpg
# train/bicycles/bicycles_0070.jpg
# test/bicycles/bicycles_0021.jpg
# test/bicycles/bicycles_0022.jpg
# test/bicycles/bicycles_0023.jpg
# train/bicycles/bicycles_0071.jpg
# test/bicycles/bicycles_0024.jpg
# train/bicycles/bicycles_0072.jpg
# train/bicycles/bicycles_0073.jpg
# train/bicycles/bicycles_0074.jpg
# train/bicycles/bicycles_0075.jpg
# test/bicycles/bicycles_0025.jpg
# train/bicycles/bicycles_0076.jpg
# train/bicycles/bicycles_0077.jpg
# train/bicycles/bicycles_0078.jpg
# train/bicycles/bicycles_0079.jpg
# train/bicycles/bicycles_0080.jpg
# train/bicycles/bicycles_0081.jpg
# train/bicycles/bicycles_0082.jpg
# train/bicycles/bicycles_0083.jpg
# train/bicycles/bicycles_0084.jpg
# train/bicycles/bicycles_0085.jpg
# train/bicycles/bicycles_0086.jpg
# train/bicycles/bicycles_0087.jpg
# train/bicycles/bicycles_0088.jpg
# train/bicycles/bicycles_0089.jpg
# test/bicycles/bicycles_0026.jpg
# test/bicycles/bicycles_0027.jpg
# test/bicycles/bicycles_0028.jpg
# test/bicycles/bicycles_0029.jpg
# train/bicycles/bicycles_0090.jpg
# test/bicycles/bicycles_0030.jpg
# train/bicycles/bicycles_0091.jpg
# train/bicycles/bicycles_0092.jpg
# train/bicycles/bicycles_0093.jpg
# train/bicycles/bicycles_0094.jpg
# train/bicycles/bicycles_0095.jpg
# train/bicycles/bicycles_0096.jpg
# train/bicycles/bicycles_0097.jpg
# train/bicycles/bicycles_0098.jpg
# train/bicycles/bicycles_0099.jpg
# train/bicycles/bicycles_0100.jpg
# train/bicycles/bicycles_0101.jpg
# train/bicycles/bicycles_0102.jpg
# train/bicycles/bicycles_0103.jpg
# train/bicycles/bicycles_0104.jpg
# train/bicycles/bicycles_0105.jpg
# train/bicycles/bicycles_0106.jpg
# train/bicycles/bicycles_0107.jpg
# train/bicycles/bicycles_0108.jpg
# train/bicycles/bicycles_0109.jpg
# train/bicycles/bicycles_0110.jpg
# train/bicycles/bicycles_0111.jpg
# train/bicycles/bicycles_0112.jpg
# train/bicycles/bicycles_0113.jpg
# test/bicycles/bicycles_0031.jpg
# train/bicycles/bicycles_0114.jpg
# train/bicycles/bicycles_0115.jpg
# train/bicycles/bicycles_0116.jpg
# test/bicycles/bicycles_0032.jpg
# train/bicycles/bicycles_0117.jpg
# train/bicycles/bicycles_0118.jpg
# train/bicycles/bicycles_0119.jpg
# train/bicycles/bicycles_0120.jpg
# train/bicycles/bicycles_0121.jpg
# train/bicycles/bicycles_0122.jpg
# train/bicycles/bicycles_0123.jpg
# train/bicycles/bicycles_0124.jpg
# train/bicycles/bicycles_0125.jpg
# test/bicycles/bicycles_0033.jpg
# test/bicycles/bicycles_0034.jpg
# train/bicycles/bicycles_0126.jpg
# train/bicycles/bicycles_0127.jpg
# train/bicycles/bicycles_0128.jpg
# train/bicycles/bicycles_0129.jpg
# train/bicycles/bicycles_0130.jpg
# train/bicycles/bicycles_0131.jpg
# train/bicycles/bicycles_0132.jpg
# train/bicycles/bicycles_0133.jpg
# train/bicycles/bicycles_0134.jpg
# test/bicycles/bicycles_0035.jpg
# test/bicycles/bicycles_0036.jpg
# train/bicycles/bicycles_0135.jpg
# test/bicycles/bicycles_0037.jpg
# train/bicycles/bicycles_0136.jpg
# test/bicycles/bicycles_0038.jpg
# train/bicycles/bicycles_0137.jpg
# train/bicycles/bicycles_0138.jpg
# train/bicycles/bicycles_0139.jpg
# train/bicycles/bicycles_0140.jpg
# test/bicycles/bicycles_0039.jpg
# train/bicycles/bicycles_0141.jpg
# test/bicycles/bicycles_0040.jpg
# test/bicycles/bicycles_0041.jpg
# train/bicycles/bicycles_0142.jpg
# train/bicycles/bicycles_0143.jpg
# test/bicycles/bicycles_0042.jpg
# test/bicycles/bicycles_0043.jpg
# train/bicycles/bicycles_0144.jpg
# train/bicycles/bicycles_0145.jpg
# train/bicycles/bicycles_0146.jpg
# train/bicycles/bicycles_0147.jpg
# train/bicycles/bicycles_0148.jpg
# train/bicycles/bicycles_0149.jpg
# train/bicycles/bicycles_0150.jpg
# train/bicycles/bicycles_0151.jpg
# train/bicycles/bicycles_0152.jpg
# train/bicycles/bicycles_0153.jpg
# train/bicycles/bicycles_0154.jpg
# train/bicycles/bicycles_0155.jpg
# train/bicycles/bicycles_0156.jpg
# test/bicycles/bicycles_0044.jpg
# test/bicycles/bicycles_0045.jpg
# train/bicycles/bicycles_0157.jpg
# train/bicycles/bicycles_0158.jpg
# train/bicycles/bicycles_0159.jpg
# test/bicycles/bicycles_0046.jpg
# test/bicycles/bicycles_0047.jpg
# train/bicycles/bicycles_0160.jpg
# train/bicycles/bicycles_0161.jpg
# train/bicycles/bicycles_0162.jpg
# test/bicycles/bicycles_0048.jpg
# test/bicycles/bicycles_0049.jpg
# train/bicycles/bicycles_0163.jpg
# test/bicycles/bicycles_0050.jpg
# train/bicycles/bicycles_0164.jpg
# train/bicycles/bicycles_0165.jpg
# test/bicycles/bicycles_0051.jpg
# train/bicycles/bicycles_0166.jpg
# train/bicycles/bicycles_0167.jpg
# train/bicycles/bicycles_0168.jpg
# train/bicycles/bicycles_0169.jpg
# test/bicycles/bicycles_0052.jpg
# train/bicycles/bicycles_0170.jpg
# train/bicycles/bicycles_0171.jpg
# train/bicycles/bicycles_0172.jpg
# test/bicycles/bicycles_0053.jpg
# train/bicycles/bicycles_0173.jpg
# train/bicycles/bicycles_0174.jpg
# train/bicycles/bicycles_0175.jpg
# test/bicycles/bicycles_0054.jpg
# train/bicycles/bicycles_0176.jpg
# test/bicycles/bicycles_0055.jpg
# test/bicycles/bicycles_0056.jpg
# train/bicycles/bicycles_0177.jpg
# train/bicycles/bicycles_0178.jpg
# train/bicycles/bicycles_0179.jpg
# train/bicycles/bicycles_0180.jpg
# train/bicycles/bicycles_0181.jpg
# test/bicycles/bicycles_0057.jpg
# test/bicycles/bicycles_0058.jpg
# test/bicycles/bicycles_0059.jpg
# train/bicycles/bicycles_0182.jpg
# train/bicycles/bicycles_0183.jpg
# test/bicycles/bicycles_0060.jpg
# train/bicycles/bicycles_0184.jpg
# train/bicycles/bicycles_0185.jpg
# train/bicycles/bicycles_0186.jpg
# train/bicycles/bicycles_0187.jpg
# train/bicycles/bicycles_0188.jpg
# test/bicycles/bicycles_0061.jpg
# train/bicycles/bicycles_0189.jpg
# test/bicycles/bicycles_0062.jpg
# train/bicycles/bicycles_0190.jpg
# train/bicycles/bicycles_0191.jpg
# test/bicycles/bicycles_0063.jpg
# test/bicycles/bicycles_0064.jpg
# train/bicycles/bicycles_0192.jpg
# train/bicycles/bicycles_0193.jpg
# train/bicycles/bicycles_0194.jpg
# train/bicycles/bicycles_0195.jpg
# test/bicycles/bicycles_0065.jpg
# train/bicycles/bicycles_0196.jpg
# train/bicycles/bicycles_0197.jpg
# test/bicycles/bicycles_0066.jpg
# train/bicycles/bicycles_0198.jpg
# train/bicycles/bicycles_0199.jpg
# train/bicycles/bicycles_0200.jpg
# train/bicycles/bicycles_0201.jpg
# train/bicycles/bicycles_0202.jpg
# train/bicycles/bicycles_0203.jpg
# test/bicycles/bicycles_0067.jpg
# train/bicycles/bicycles_0204.jpg
# test/bicycles/bicycles_0068.jpg
# test/bicycles/bicycles_0069.jpg
# train/bicycles/bicycles_0205.jpg
# train/bicycles/bicycles_0206.jpg
# train/bicycles/bicycles_0207.jpg
# train/bicycles/bicycles_0208.jpg
# train/bicycles/bicycles_0209.jpg
# train/bicycles/bicycles_0210.jpg
# train/bicycles/bicycles_0211.jpg
# test/bicycles/bicycles_0070.jpg
# train/bicycles/bicycles_0212.jpg
# train/bicycles/bicycles_0213.jpg
# train/bicycles/bicycles_0214.jpg
# train/bicycles/bicycles_0215.jpg
# train/bicycles/bicycles_0216.jpg
# test/bicycles/bicycles_0071.jpg
# test/bicycles/bicycles_0072.jpg
# test/bicycles/bicycles_0073.jpg
# train/bicycles/bicycles_0217.jpg
# train/bicycles/bicycles_0218.jpg
# train/bicycles/bicycles_0219.jpg
# test/bicycles/bicycles_0074.jpg
# train/bicycles/bicycles_0220.jpg
# train/bicycles/bicycles_0221.jpg
# train/bicycles/bicycles_0222.jpg
# train/bicycles/bicycles_0223.jpg
# train/bicycles/bicycles_0224.jpg
# train/bicycles/bicycles_0225.jpg
# train/bicycles/bicycles_0226.jpg
# train/bicycles/bicycles_0227.jpg
# train/bicycles/bicycles_0228.jpg
# test/bicycles/bicycles_0075.jpg
# train/bicycles/bicycles_0229.jpg
# train/bicycles/bicycles_0230.jpg
# train/bicycles/bicycles_0231.jpg
# test/bicycles/bicycles_0076.jpg
# train/bicycles/bicycles_0232.jpg
# train/bicycles/bicycles_0233.jpg
# train/bicycles/bicycles_0234.jpg
# train/bicycles/bicycles_0235.jpg
# test/bicycles/bicycles_0077.jpg
# test/bicycles/bicycles_0078.jpg
# train/bicycles/bicycles_0236.jpg
# train/bicycles/bicycles_0237.jpg
# train/bicycles/bicycles_0238.jpg
# train/bicycles/bicycles_0239.jpg
# train/bicycles/bicycles_0240.jpg
# train/bicycles/bicycles_0241.jpg
# train/bicycles/bicycles_0242.jpg
# train/bicycles/bicycles_0243.jpg
# train/bicycles/bicycles_0244.jpg
# train/bicycles/bicycles_0245.jpg
# train/bicycles/bicycles_0246.jpg
# train/bicycles/bicycles_0247.jpg
# train/bicycles/bicycles_0248.jpg
# train/bicycles/bicycles_0249.jpg
# test/bicycles/bicycles_0079.jpg
# train/bicycles/bicycles_0250.jpg
# test/bicycles/bicycles_0080.jpg
# train/bicycles/bicycles_0251.jpg
# train/bicycles/bicycles_0252.jpg
# test/bicycles/bicycles_0081.jpg
# train/bicycles/bicycles_0253.jpg
# test/bicycles/bicycles_0082.jpg
# train/bicycles/bicycles_0254.jpg
# test/bicycles/bicycles_0083.jpg
# test/bicycles/bicycles_0084.jpg
# test/bicycles/bicycles_0085.jpg
# train/bicycles/bicycles_0255.jpg
# train/bicycles/bicycles_0256.jpg
# train/bicycles/bicycles_0257.jpg
# test/bicycles/bicycles_0086.jpg
# train/bicycles/bicycles_0258.jpg
# test/bicycles/bicycles_0087.jpg
# train/bicycles/bicycles_0259.jpg
# test/bicycles/bicycles_0088.jpg
# train/bicycles/bicycles_0260.jpg
# train/bicycles/bicycles_0261.jpg
# test/bicycles/bicycles_0089.jpg
# test/bicycles/bicycles_0090.jpg
# test/bicycles/bicycles_0091.jpg
# test/bicycles/bicycles_0092.jpg
# train/bicycles/bicycles_0262.jpg
# train/bicycles/bicycles_0263.jpg
# train/bicycles/bicycles_0264.jpg
# train/bicycles/bicycles_0265.jpg
# train/bicycles/bicycles_0266.jpg
# train/bicycles/bicycles_0267.jpg
# train/bicycles/bicycles_0268.jpg
# train/bicycles/bicycles_0269.jpg
# train/bicycles/bicycles_0270.jpg
# test/bicycles/bicycles_0093.jpg
# test/bicycles/bicycles_0094.jpg
# train/bicycles/bicycles_0271.jpg
# train/bicycles/bicycles_0272.jpg
# test/bicycles/bicycles_0095.jpg
# train/bicycles/bicycles_0273.jpg
# train/bicycles/bicycles_0274.jpg
# train/bicycles/bicycles_0275.jpg
# train/bicycles/bicycles_0276.jpg
# train/bicycles/bicycles_0277.jpg
# train/bicycles/bicycles_0278.jpg
# train/bicycles/bicycles_0279.jpg
# train/bicycles/bicycles_0280.jpg
# train/bicycles/bicycles_0281.jpg
# train/bicycles/bicycles_0282.jpg
# train/bicycles/bicycles_0283.jpg
# train/bicycles/bicycles_0284.jpg
# train/bicycles/bicycles_0285.jpg
# test/bicycles/bicycles_0096.jpg
# train/bicycles/bicycles_0286.jpg
# train/bicycles/bicycles_0287.jpg
# train/bicycles/bicycles_0288.jpg
# train/bicycles/bicycles_0289.jpg
# train/bicycles/bicycles_0290.jpg
# train/bicycles/bicycles_0291.jpg
# train/bicycles/bicycles_0292.jpg
# train/bicycles/bicycles_0293.jpg
# train/bicycles/bicycles_0294.jpg
# train/bicycles/bicycles_0295.jpg
# train/bicycles/bicycles_0296.jpg
# train/bicycles/bicycles_0297.jpg
# train/bicycles/bicycles_0298.jpg
# train/bicycles/bicycles_0299.jpg
# train/bicycles/bicycles_0300.jpg
# train/bicycles/bicycles_0301.jpg
# train/bicycles/bicycles_0302.jpg
# test/bicycles/bicycles_0097.jpg
# test/bicycles/bicycles_0098.jpg
# train/bicycles/bicycles_0303.jpg
# train/bicycles/bicycles_0304.jpg
# train/bicycles/bicycles_0305.jpg
# train/bicycles/bicycles_0306.jpg
# train/bicycles/bicycles_0307.jpg
# test/bicycles/bicycles_0099.jpg
# train/bicycles/bicycles_0308.jpg
# train/bicycles/bicycles_0309.jpg
# test/bicycles/bicycles_0100.jpg
# train/bicycles/bicycles_0310.jpg
# train/bicycles/bicycles_0311.jpg
# test/bicycles/bicycles_0101.jpg
# train/bicycles/bicycles_0312.jpg
# train/bicycles/bicycles_0313.jpg
# train/bicycles/bicycles_0314.jpg
# train/bicycles/bicycles_0315.jpg
# test/bicycles/bicycles_0102.jpg
# test/bicycles/bicycles_0103.jpg
# test/bicycles/bicycles_0104.jpg
# train/bicycles/bicycles_0316.jpg
# train/bicycles/bicycles_0317.jpg
# train/bicycles/bicycles_0318.jpg
# train/bicycles/bicycles_0319.jpg
# train/bicycles/bicycles_0320.jpg
# train/bicycles/bicycles_0321.jpg
# train/bicycles/bicycles_0322.jpg
# train/bicycles/bicycles_0323.jpg
# train/bicycles/bicycles_0324.jpg
# train/bicycles/bicycles_0325.jpg
# train/bicycles/bicycles_0326.jpg
# train/bicycles/bicycles_0327.jpg
# train/bicycles/bicycles_0328.jpg
# train/bicycles/bicycles_0329.jpg
# test/bicycles/bicycles_0105.jpg
# test/bicycles/bicycles_0106.jpg
# train/bicycles/bicycles_0330.jpg
# train/bicycles/bicycles_0331.jpg
# test/bicycles/bicycles_0107.jpg
# test/bicycles/bicycles_0108.jpg
# train/bicycles/bicycles_0332.jpg
# train/bicycles/bicycles_0333.jpg
# test/bicycles/bicycles_0109.jpg
# train/bicycles/bicycles_0334.jpg
# train/bicycles/bicycles_0335.jpg
# train/bicycles/bicycles_0336.jpg
# test/bicycles/bicycles_0110.jpg
# test/bicycles/bicycles_0111.jpg
# train/bicycles/bicycles_0337.jpg
# test/bicycles/bicycles_0112.jpg
# train/bicycles/bicycles_0338.jpg
# train/bicycles/bicycles_0339.jpg
# train/bicycles/bicycles_0340.jpg
# train/bicycles/bicycles_0341.jpg
# test/bicycles/bicycles_0113.jpg
# test/bicycles/bicycles_0114.jpg
# train/bicycles/bicycles_0342.jpg
# train/bicycles/bicycles_0343.jpg
# train/bicycles/bicycles_0344.jpg
# train/bicycles/bicycles_0345.jpg
# train/bicycles/bicycles_0346.jpg
# train/bicycles/bicycles_0347.jpg
# train/bicycles/bicycles_0348.jpg
# train/bicycles/bicycles_0349.jpg
# train/bicycles/bicycles_0350.jpg
# train/bicycles/bicycles_0351.jpg
# train/bicycles/bicycles_0352.jpg
# train/bicycles/bicycles_0353.jpg
# train/bicycles/bicycles_0354.jpg
# test/bicycles/bicycles_0115.jpg
# train/bicycles/bicycles_0355.jpg
# train/bicycles/bicycles_0356.jpg
# train/bicycles/bicycles_0357.jpg
# train/bicycles/bicycles_0358.jpg
# train/bicycles/bicycles_0359.jpg
# train/bicycles/bicycles_0360.jpg
# train/bicycles/bicycles_0361.jpg
# test/bicycles/bicycles_0116.jpg
# test/bicycles/bicycles_0117.jpg
# test/bicycles/bicycles_0118.jpg
# train/bicycles/bicycles_0362.jpg
# train/bicycles/bicycles_0363.jpg
# test/bicycles/bicycles_0119.jpg
# train/bicycles/bicycles_0364.jpg
# train/bicycles/bicycles_0365.jpg
# train/bicycles/bicycles_0366.jpg
# train/bicycles/bicycles_0367.jpg
# train/bicycles/bicycles_0368.jpg
# test/bicycles/bicycles_0120.jpg
# train/bicycles/bicycles_0369.jpg
# train/bicycles/bicycles_0370.jpg
# train/bicycles/bicycles_0371.jpg
# test/bicycles/bicycles_0121.jpg
# train/bicycles/bicycles_0372.jpg
# test/bicycles/bicycles_0122.jpg
# train/bicycles/bicycles_0373.jpg
# train/bicycles/bicycles_0374.jpg
# train/bicycles/bicycles_0375.jpg
# train/bicycles/bicycles_0376.jpg
# train/bicycles/bicycles_0377.jpg
# train/bicycles/bicycles_0378.jpg
# train/bicycles/bicycles_0379.jpg
# train/bicycles/bicycles_0380.jpg
# train/bicycles/bicycles_0381.jpg
# train/bicycles/bicycles_0382.jpg
# train/bicycles/bicycles_0383.jpg
# train/bicycles/bicycles_0384.jpg
# test/bicycles/bicycles_0123.jpg
# train/bicycles/bicycles_0385.jpg
# train/bicycles/bicycles_0386.jpg
# train/bicycles/bicycles_0387.jpg
# train/bicycles/bicycles_0388.jpg
# train/bicycles/bicycles_0389.jpg
# train/bicycles/bicycles_0390.jpg
# train/bicycles/bicycles_0391.jpg
# train/bicycles/bicycles_0392.jpg
# test/bicycles/bicycles_0124.jpg
# test/bicycles/bicycles_0125.jpg
# train/bicycles/bicycles_0393.jpg
# test/bicycles/bicycles_0126.jpg
# train/bicycles/bicycles_0394.jpg
# test/bicycles/bicycles_0127.jpg
# train/bicycles/bicycles_0395.jpg
# train/bicycles/bicycles_0396.jpg
# test/bicycles/bicycles_0128.jpg
# train/bicycles/bicycles_0397.jpg
# train/bicycles/bicycles_0398.jpg
# train/bicycles/bicycles_0399.jpg
# train/bicycles/bicycles_0400.jpg
# train/bicycles/bicycles_0401.jpg
# train/bicycles/bicycles_0402.jpg
# train/bicycles/bicycles_0403.jpg
# train/bicycles/bicycles_0404.jpg
# train/bicycles/bicycles_0405.jpg
# test/bicycles/bicycles_0129.jpg
# train/bicycles/bicycles_0406.jpg
# train/bicycles/bicycles_0407.jpg
# test/bicycles/bicycles_0130.jpg
# train/bicycles/bicycles_0408.jpg
# train/bicycles/bicycles_0409.jpg
# train/bicycles/bicycles_0410.jpg
# train/bicycles/bicycles_0411.jpg
# train/bicycles/bicycles_0412.jpg
# train/bicycles/bicycles_0413.jpg
# train/bicycles/bicycles_0414.jpg
# train/bicycles/bicycles_0415.jpg
# train/bicycles/bicycles_0416.jpg
# test/bicycles/bicycles_0131.jpg
# test/bicycles/bicycles_0132.jpg
# test/bicycles/bicycles_0133.jpg
# train/bicycles/bicycles_0417.jpg
# test/bicycles/bicycles_0134.jpg
# train/bicycles/bicycles_0418.jpg
# train/bicycles/bicycles_0419.jpg
# train/bicycles/bicycles_0420.jpg
# train/bicycles/bicycles_0421.jpg
# test/bicycles/bicycles_0135.jpg
# train/bicycles/bicycles_0422.jpg
# train/bicycles/bicycles_0423.jpg
# test/bicycles/bicycles_0136.jpg
# train/bicycles/bicycles_0424.jpg
# train/bicycles/bicycles_0425.jpg
# train/bicycles/bicycles_0426.jpg
# train/bicycles/bicycles_0427.jpg
# train/bicycles/bicycles_0428.jpg
# train/bicycles/bicycles_0429.jpg
# train/bicycles/bicycles_0430.jpg
# train/bicycles/bicycles_0431.jpg
# train/bicycles/bicycles_0432.jpg
# train/bicycles/bicycles_0433.jpg
# test/bicycles/bicycles_0137.jpg
# train/bicycles/bicycles_0434.jpg
# train/bicycles/bicycles_0435.jpg
# train/bicycles/bicycles_0436.jpg
# train/bicycles/bicycles_0437.jpg
# train/bicycles/bicycles_0438.jpg
# train/bicycles/bicycles_0439.jpg
# test/bicycles/bicycles_0138.jpg
# train/bicycles/bicycles_0440.jpg
# train/bicycles/bicycles_0441.jpg
# test/bicycles/bicycles_0139.jpg
# train/bicycles/bicycles_0442.jpg
# train/bicycles/bicycles_0443.jpg
# train/bicycles/bicycles_0444.jpg
# train/bicycles/bicycles_0445.jpg
# train/bicycles/bicycles_0446.jpg
# train/bicycles/bicycles_0447.jpg
# train/bicycles/bicycles_0448.jpg
# test/bicycles/bicycles_0140.jpg
# train/bicycles/bicycles_0449.jpg
# train/bicycles/bicycles_0450.jpg
# train/bicycles/bicycles_0451.jpg
# train/bicycles/bicycles_0452.jpg
# train/bicycles/bicycles_0453.jpg
# test/bicycles/bicycles_0141.jpg
# test/bicycles/bicycles_0142.jpg
# train/bicycles/bicycles_0454.jpg
# train/bicycles/bicycles_0455.jpg
# test/bicycles/bicycles_0143.jpg
# train/bicycles/bicycles_0456.jpg
# test/bicycles/bicycles_0144.jpg
# train/bicycles/bicycles_0457.jpg
# test/bicycles/bicycles_0145.jpg
# train/bicycles/bicycles_0458.jpg
# train/bicycles/bicycles_0459.jpg
# train/bicycles/bicycles_0460.jpg
# train/bicycles/bicycles_0461.jpg
# test/bicycles/bicycles_0146.jpg
# train/bicycles/bicycles_0462.jpg
# train/bicycles/bicycles_0463.jpg
# train/bicycles/bicycles_0464.jpg
# test/bicycles/bicycles_0147.jpg
# train/bicycles/bicycles_0465.jpg
# test/bicycles/bicycles_0148.jpg
# train/bicycles/bicycles_0466.jpg
# train/bicycles/bicycles_0467.jpg
# train/bicycles/bicycles_0468.jpg
# train/bicycles/bicycles_0469.jpg
# train/bicycles/bicycles_0470.jpg
# train/bicycles/bicycles_0471.jpg
# train/bicycles/bicycles_0472.jpg
# train/bicycles/bicycles_0473.jpg
# train/bicycles/bicycles_0474.jpg
# train/bicycles/bicycles_0475.jpg
# train/bicycles/bicycles_0476.jpg
# train/bicycles/bicycles_0477.jpg
# train/bicycles/bicycles_0478.jpg
# train/bicycles/bicycles_0479.jpg
# train/bicycles/bicycles_0480.jpg
# train/bicycles/bicycles_0481.jpg
# train/bicycles/bicycles_0482.jpg
# train/bicycles/bicycles_0483.jpg
# train/bicycles/bicycles_0484.jpg
# train/bicycles/bicycles_0485.jpg
# test/bicycles/bicycles_0149.jpg
# train/bicycles/bicycles_0486.jpg
# train/bicycles/bicycles_0487.jpg
# train/bicycles/bicycles_0488.jpg
# test/bicycles/bicycles_0150.jpg
# test/bicycles/bicycles_0151.jpg
# train/bicycles/bicycles_0489.jpg
# train/bicycles/bicycles_0490.jpg
# test/bicycles/bicycles_0152.jpg
# train/bicycles/bicycles_0491.jpg
# train/bicycles/bicycles_0492.jpg
# train/bicycles/bicycles_0493.jpg
# train/bicycles/bicycles_0494.jpg
# train/bicycles/bicycles_0495.jpg
# train/bicycles/bicycles_0496.jpg
# train/bicycles/bicycles_0497.jpg
# train/bicycles/bicycles_0498.jpg
# test/bicycles/bicycles_0153.jpg
# train/bicycles/bicycles_0499.jpg
# train/bicycles/bicycles_0500.jpg
# train/bicycles/bicycles_0501.jpg
# train/bicycles/bicycles_0502.jpg
# train/bicycles/bicycles_0503.jpg
# train/bicycles/bicycles_0504.jpg
# test/bicycles/bicycles_0154.jpg
# test/bicycles/bicycles_0155.jpg
# train/bicycles/bicycles_0505.jpg
# test/bicycles/bicycles_0156.jpg
# test/bicycles/bicycles_0157.jpg
# train/bicycles/bicycles_0506.jpg
# train/bicycles/bicycles_0507.jpg
# train/bicycles/bicycles_0508.jpg
# test/bicycles/bicycles_0158.jpg
# train/bicycles/bicycles_0509.jpg
# test/bicycles/bicycles_0159.jpg
# train/bicycles/bicycles_0510.jpg
# train/bicycles/bicycles_0511.jpg
# test/bicycles/bicycles_0160.jpg
# train/bicycles/bicycles_0512.jpg
# train/bicycles/bicycles_0513.jpg
# train/bicycles/bicycles_0514.jpg
# train/bicycles/bicycles_0515.jpg
# train/bicycles/bicycles_0516.jpg
# train/bicycles/bicycles_0517.jpg
# train/bicycles/bicycles_0518.jpg
# test/bicycles/bicycles_0161.jpg
# test/bicycles/bicycles_0162.jpg
# train/bicycles/bicycles_0519.jpg
# train/bicycles/bicycles_0520.jpg
# test/bicycles/bicycles_0163.jpg
# train/bicycles/bicycles_0521.jpg
# train/bicycles/bicycles_0522.jpg
# train/bicycles/bicycles_0523.jpg
# train/bicycles/bicycles_0524.jpg
# train/bicycles/bicycles_0525.jpg
# train/bicycles/bicycles_0526.jpg
# train/bicycles/bicycles_0527.jpg
# train/bicycles/bicycles_0528.jpg
# test/bicycles/bicycles_0164.jpg
# train/bicycles/bicycles_0529.jpg
# train/bicycles/bicycles_0530.jpg
# train/bicycles/bicycles_0531.jpg
# test/bicycles/bicycles_0165.jpg
# train/bicycles/bicycles_0532.jpg
# train/bicycles/bicycles_0533.jpg
# train/bicycles/bicycles_0534.jpg
# test/bicycles/bicycles_0166.jpg
# train/bicycles/bicycles_0535.jpg
# train/bicycles/bicycles_0536.jpg
# train/bicycles/bicycles_0537.jpg
# train/bicycles/bicycles_0538.jpg
# train/bicycles/bicycles_0539.jpg
# train/bicycles/bicycles_0540.jpg
# train/bicycles/bicycles_0541.jpg
# train/bicycles/bicycles_0542.jpg
# train/bicycles/bicycles_0543.jpg
# test/bicycles/bicycles_0167.jpg
# train/bicycles/bicycles_0544.jpg
# train/bicycles/bicycles_0545.jpg
# train/bicycles/bicycles_0546.jpg
# train/bicycles/bicycles_0547.jpg
# train/bicycles/bicycles_0548.jpg
# train/bicycles/bicycles_0549.jpg
# train/bicycles/bicycles_0550.jpg
# test/bicycles/bicycles_0168.jpg
# train/bicycles/bicycles_0551.jpg
# test/bicycles/bicycles_0169.jpg
# test/bicycles/bicycles_0170.jpg
# test/bicycles/bicycles_0171.jpg
# train/bicycles/bicycles_0552.jpg
# train/bicycles/bicycles_0553.jpg
# test/bicycles/bicycles_0172.jpg
# train/bicycles/bicycles_0554.jpg
# train/bicycles/bicycles_0555.jpg
# test/bicycles/bicycles_0173.jpg
# train/bicycles/bicycles_0556.jpg
# train/bicycles/bicycles_0557.jpg
# train/bicycles/bicycles_0558.jpg
# train/bicycles/bicycles_0559.jpg
# train/bicycles/bicycles_0560.jpg
# train/bicycles/bicycles_0561.jpg
# test/bicycles/bicycles_0174.jpg
# train/bicycles/bicycles_0562.jpg
# train/bicycles/bicycles_0563.jpg
# train/bicycles/bicycles_0564.jpg
# test/bicycles/bicycles_0175.jpg
# train/bicycles/bicycles_0565.jpg
# train/bicycles/bicycles_0566.jpg
# train/bicycles/bicycles_0567.jpg
# train/bicycles/bicycles_0568.jpg
# train/bicycles/bicycles_0569.jpg
# train/bicycles/bicycles_0570.jpg
# test/bicycles/bicycles_0176.jpg
# test/bicycles/bicycles_0177.jpg
# test/bicycles/bicycles_0178.jpg
# train/bicycles/bicycles_0571.jpg
# train/bicycles/bicycles_0572.jpg
# train/bicycles/bicycles_0573.jpg
# train/bicycles/bicycles_0574.jpg
# train/bicycles/bicycles_0575.jpg
# train/bicycles/bicycles_0576.jpg
# test/bicycles/bicycles_0179.jpg
# test/bicycles/bicycles_0180.jpg
# train/bicycles/bicycles_0577.jpg
# train/bicycles/bicycles_0578.jpg
# train/bicycles/bicycles_0579.jpg
# train/bicycles/bicycles_0580.jpg
# test/bicycles/bicycles_0181.jpg
# train/bicycles/bicycles_0581.jpg
# test/bicycles/bicycles_0182.jpg
# train/bicycles/bicycles_0582.jpg
# train/bicycles/bicycles_0583.jpg
# test/bicycles/bicycles_0183.jpg
# test/bicycles/bicycles_0184.jpg
# train/bicycles/bicycles_0584.jpg
# train/bicycles/bicycles_0585.jpg
# train/bicycles/bicycles_0586.jpg
# train/bicycles/bicycles_0587.jpg
# train/bicycles/bicycles_0588.jpg
# train/bicycles/bicycles_0589.jpg
# train/bicycles/bicycles_0590.jpg
# train/bicycles/bicycles_0591.jpg
# test/bicycles/bicycles_0185.jpg
# train/bicycles/bicycles_0592.jpg
# train/bicycles/bicycles_0593.jpg
# train/bicycles/bicycles_0594.jpg
# train/bicycles/bicycles_0595.jpg
# train/bicycles/bicycles_0596.jpg
# train/bicycles/bicycles_0597.jpg
# train/bicycles/bicycles_0598.jpg
# train/bicycles/bicycles_0599.jpg
# train/bicycles/bicycles_0600.jpg
# test/bicycles/bicycles_0186.jpg
# train/bicycles/bicycles_0601.jpg
# train/bicycles/bicycles_0602.jpg
# train/bicycles/bicycles_0603.jpg
# test/bicycles/bicycles_0187.jpg
# train/bicycles/bicycles_0604.jpg
# test/bicycles/bicycles_0188.jpg
# test/bicycles/bicycles_0189.jpg
# test/bicycles/bicycles_0190.jpg
# test/bicycles/bicycles_0191.jpg
# test/bicycles/bicycles_0192.jpg
# test/bicycles/bicycles_0193.jpg
# test/bicycles/bicycles_0194.jpg
# train/bicycles/bicycles_0605.jpg
# train/bicycles/bicycles_0606.jpg
# train/bicycles/bicycles_0607.jpg
# test/bicycles/bicycles_0195.jpg
# train/bicycles/bicycles_0608.jpg
# train/bicycles/bicycles_0609.jpg
# train/bicycles/bicycles_0610.jpg
# train/bicycles/bicycles_0611.jpg
# test/bicycles/bicycles_0196.jpg
# train/bicycles/bicycles_0612.jpg
# train/bicycles/bicycles_0613.jpg
# train/bicycles/bicycles_0614.jpg
# test/bicycles/bicycles_0197.jpg
# train/bicycles/bicycles_0615.jpg
# train/bicycles/bicycles_0616.jpg
# train/bicycles/bicycles_0617.jpg
# train/bicycles/bicycles_0618.jpg
# train/bicycles/bicycles_0619.jpg
# test/bicycles/bicycles_0198.jpg
# train/bicycles/bicycles_0620.jpg
# train/bicycles/bicycles_0621.jpg
# train/bicycles/bicycles_0622.jpg
# train/bicycles/bicycles_0623.jpg
# train/bicycles/bicycles_0624.jpg
# train/bicycles/bicycles_0625.jpg
# train/bicycles/bicycles_0626.jpg
# train/bicycles/bicycles_0627.jpg
# train/bicycles/bicycles_0628.jpg
# train/bicycles/bicycles_0629.jpg
# train/bicycles/bicycles_0630.jpg
# train/bicycles/bicycles_0631.jpg
# train/bicycles/bicycles_0632.jpg
# test/bicycles/bicycles_0199.jpg
# train/bicycles/bicycles_0633.jpg
# train/bicycles/bicycles_0634.jpg
# test/bicycles/bicycles_0200.jpg
# train/bicycles/bicycles_0635.jpg
# train/bicycles/bicycles_0636.jpg
# test/bicycles/bicycles_0201.jpg
# train/bicycles/bicycles_0637.jpg
# train/bicycles/bicycles_0638.jpg
# test/bicycles/bicycles_0202.jpg
# train/bicycles/bicycles_0639.jpg
# test/bicycles/bicycles_0203.jpg
# test/bicycles/bicycles_0204.jpg
# train/bicycles/bicycles_0640.jpg
# train/bicycles/bicycles_0641.jpg
# train/bicycles/bicycles_0642.jpg
# test/bicycles/bicycles_0205.jpg
# test/bicycles/bicycles_0206.jpg
# train/bicycles/bicycles_0643.jpg
# test/bicycles/bicycles_0207.jpg
# test/bicycles/bicycles_0208.jpg
# train/bicycles/bicycles_0644.jpg
# train/bicycles/bicycles_0645.jpg
# train/bicycles/bicycles_0646.jpg
# train/bicycles/bicycles_0647.jpg
# train/bicycles/bicycles_0648.jpg
# train/bicycles/bicycles_0649.jpg
# train/bicycles/bicycles_0650.jpg
# test/bicycles/bicycles_0209.jpg
# test/bicycles/bicycles_0210.jpg
# train/bicycles/bicycles_0651.jpg
# train/bicycles/bicycles_0652.jpg
# test/bicycles/bicycles_0211.jpg
# train/bicycles/bicycles_0653.jpg
# train/bicycles/bicycles_0654.jpg
# train/bicycles/bicycles_0655.jpg
# train/bicycles/bicycles_0656.jpg
# train/bicycles/bicycles_0657.jpg
# train/bicycles/bicycles_0658.jpg
# train/bicycles/bicycles_0659.jpg
# test/bicycles/bicycles_0212.jpg
# train/bicycles/bicycles_0660.jpg
# test/bicycles/bicycles_0213.jpg
# train/bicycles/bicycles_0661.jpg
# train/bicycles/bicycles_0662.jpg
# train/bicycles/bicycles_0663.jpg
# train/bicycles/bicycles_0664.jpg
# train/bicycles/bicycles_0665.jpg
# test/bicycles/bicycles_0214.jpg
# test/bicycles/bicycles_0215.jpg
# train/bicycles/bicycles_0666.jpg
# train/bicycles/bicycles_0667.jpg
# train/bicycles/bicycles_0668.jpg
# train/bicycles/bicycles_0669.jpg
# train/bicycles/bicycles_0670.jpg
# train/bicycles/bicycles_0671.jpg
# train/bicycles/bicycles_0672.jpg
# test/bicycles/bicycles_0216.jpg
# train/bicycles/bicycles_0673.jpg
# train/bicycles/bicycles_0674.jpg
# test/bicycles/bicycles_0217.jpg
# train/bicycles/bicycles_0675.jpg
# train/bicycles/bicycles_0676.jpg
# train/bicycles/bicycles_0677.jpg
# train/bicycles/bicycles_0678.jpg
# test/bicycles/bicycles_0218.jpg
# test/bicycles/bicycles_0219.jpg
# train/bicycles/bicycles_0679.jpg
# test/bicycles/bicycles_0220.jpg
# test/bicycles/bicycles_0221.jpg
# test/bicycles/bicycles_0222.jpg
# train/bicycles/bicycles_0680.jpg
# train/bicycles/bicycles_0681.jpg
# train/bicycles/bicycles_0682.jpg
# train/bicycles/bicycles_0683.jpg
# train/bicycles/bicycles_0684.jpg
# train/bicycles/bicycles_0685.jpg
# train/bicycles/bicycles_0686.jpg
# train/bicycles/bicycles_0687.jpg
# train/bicycles/bicycles_0688.jpg
# train/bicycles/bicycles_0689.jpg
# train/bicycles/bicycles_0690.jpg
# train/bicycles/bicycles_0691.jpg
# train/bicycles/bicycles_0692.jpg
# train/bicycles/bicycles_0693.jpg
# test/bicycles/bicycles_0223.jpg
# train/bicycles/bicycles_0694.jpg
# train/bicycles/bicycles_0695.jpg
# test/bicycles/bicycles_0224.jpg
# train/bicycles/bicycles_0696.jpg
# train/bicycles/bicycles_0697.jpg
# train/bicycles/bicycles_0698.jpg
# train/bicycles/bicycles_0699.jpg
# train/bicycles/bicycles_0700.jpg
# train/bicycles/bicycles_0701.jpg
# train/bicycles/bicycles_0702.jpg
# train/bicycles/bicycles_0703.jpg
# train/bicycles/bicycles_0704.jpg
# test/bicycles/bicycles_0225.jpg
# train/bicycles/bicycles_0705.jpg
# train/bicycles/bicycles_0706.jpg
# train/bicycles/bicycles_0707.jpg
# test/bicycles/bicycles_0226.jpg
# train/bicycles/bicycles_0708.jpg
# train/bicycles/bicycles_0709.jpg
# train/bicycles/bicycles_0710.jpg
# train/bicycles/bicycles_0711.jpg
# test/bicycles/bicycles_0227.jpg
# train/bicycles/bicycles_0712.jpg
# train/bicycles/bicycles_0713.jpg
# test/bicycles/bicycles_0228.jpg
# train/bicycles/bicycles_0714.jpg
# train/bicycles/bicycles_0715.jpg
# test/bicycles/bicycles_0229.jpg
# train/bicycles/bicycles_0716.jpg
# train/bicycles/bicycles_0717.jpg
# train/bicycles/bicycles_0718.jpg
# test/bicycles/bicycles_0230.jpg
# test/bicycles/bicycles_0231.jpg
# train/bicycles/bicycles_0719.jpg
# train/bicycles/bicycles_0720.jpg
# train/bicycles/bicycles_0721.jpg
# train/bicycles/bicycles_0722.jpg
# train/bicycles/bicycles_0723.jpg
# train/bicycles/bicycles_0724.jpg
# train/bicycles/bicycles_0725.jpg
# train/bicycles/bicycles_0726.jpg
# train/bicycles/bicycles_0727.jpg
# test/bicycles/bicycles_0232.jpg
# train/bicycles/bicycles_0728.jpg
# train/bicycles/bicycles_0729.jpg
# train/bicycles/bicycles_0730.jpg
# train/bicycles/bicycles_0731.jpg
# train/bicycles/bicycles_0732.jpg
# train/bicycles/bicycles_0733.jpg
# train/bicycles/bicycles_0734.jpg
# test/bicycles/bicycles_0233.jpg
# train/bicycles/bicycles_0735.jpg
# test/bicycles/bicycles_0234.jpg
# train/bicycles/bicycles_0736.jpg
# train/bicycles/bicycles_0737.jpg
# test/bicycles/bicycles_0235.jpg
# train/bicycles/bicycles_0738.jpg
# train/bicycles/bicycles_0739.jpg
# train/bicycles/bicycles_0740.jpg
# test/bicycles/bicycles_0236.jpg
# test/bicycles/bicycles_0237.jpg
# train/bicycles/bicycles_0741.jpg
# train/bicycles/bicycles_0742.jpg
# test/bicycles/bicycles_0238.jpg
# train/bicycles/bicycles_0743.jpg
# train/bicycles/bicycles_0744.jpg
# train/bicycles/bicycles_0745.jpg
# train/bicycles/bicycles_0746.jpg
# train/bicycles/bicycles_0747.jpg
# train/bicycles/bicycles_0748.jpg
# test/bicycles/bicycles_0239.jpg
# train/bicycles/bicycles_0749.jpg
# test/bicycles/bicycles_0240.jpg
# test/bicycles/bicycles_0241.jpg
# train/bicycles/bicycles_0750.jpg
# train/bicycles/bicycles_0751.jpg
# train/bicycles/bicycles_0752.jpg
# train/bicycles/bicycles_0753.jpg
# test/bicycles/bicycles_0242.jpg
# train/bicycles/bicycles_0754.jpg
# train/bicycles/bicycles_0755.jpg
# train/bicycles/bicycles_0756.jpg
# train/bicycles/bicycles_0757.jpg
# train/bicycles/bicycles_0758.jpg
# train/bicycles/bicycles_0759.jpg
# train/bicycles/bicycles_0760.jpg
# train/bicycles/bicycles_0761.jpg
# test/bicycles/bicycles_0243.jpg
# train/bicycles/bicycles_0762.jpg
# train/bicycles/bicycles_0763.jpg
# train/bicycles/bicycles_0764.jpg
# train/bicycles/bicycles_0765.jpg
# train/bicycles/bicycles_0766.jpg
# train/bicycles/bicycles_0767.jpg
# train/bicycles/bicycles_0768.jpg
# train/bicycles/bicycles_0769.jpg
# train/bicycles/bicycles_0770.jpg
# train/bicycles/bicycles_0771.jpg
# train/bicycles/bicycles_0772.jpg
# train/bicycles/bicycles_0773.jpg
# train/bicycles/bicycles_0774.jpg
# test/bicycles/bicycles_0244.jpg
# train/bicycles/bicycles_0775.jpg
# train/bicycles/bicycles_0776.jpg
# train/bicycles/bicycles_0777.jpg
# train/bicycles/bicycles_0778.jpg
# train/bicycles/bicycles_0779.jpg
# train/bicycles/bicycles_0780.jpg
# test/bicycles/bicycles_0245.jpg
# test/bicycles/bicycles_0246.jpg
# train/bicycles/bicycles_0781.jpg
# train/bicycles/bicycles_0782.jpg
# train/bicycles/bicycles_0783.jpg
# train/bicycles/bicycles_0784.jpg
# train/bicycles/bicycles_0785.jpg
# train/bicycles/bicycles_0786.jpg
# train/bicycles/bicycles_0787.jpg
# train/bicycles/bicycles_0788.jpg
# train/bicycles/bicycles_0789.jpg
# train/bicycles/bicycles_0790.jpg
# train/bicycles/bicycles_0791.jpg
# train/bicycles/bicycles_0792.jpg
# train/bicycles/bicycles_0793.jpg
# train/bicycles/bicycles_0794.jpg
# test/bicycles/bicycles_0247.jpg
# train/bicycles/bicycles_0795.jpg
# train/bicycles/bicycles_0796.jpg
# train/bicycles/bicycles_0797.jpg
# train/bicycles/bicycles_0798.jpg
# train/bicycles/bicycles_0799.jpg
# train/bicycles/bicycles_0800.jpg
# train/bicycles/bicycles_0801.jpg
# train/bicycles/bicycles_0802.jpg
# test/bicycles/bicycles_0248.jpg
# train/bicycles/bicycles_0803.jpg
# train/bicycles/bicycles_0804.jpg
# train/bicycles/bicycles_0805.jpg
# train/bicycles/bicycles_0806.jpg
# train/bicycles/bicycles_0807.jpg
# train/bicycles/bicycles_0808.jpg
# train/bicycles/bicycles_0809.jpg
# train/bicycles/bicycles_0810.jpg
# train/bicycles/bicycles_0811.jpg
# train/bicycles/bicycles_0812.jpg
# train/bicycles/bicycles_0813.jpg
# train/bicycles/bicycles_0814.jpg
# train/bicycles/bicycles_0815.jpg
# train/bicycles/bicycles_0816.jpg
# train/bicycles/bicycles_0817.jpg
# train/bicycles/bicycles_0818.jpg
# train/bicycles/bicycles_0819.jpg
# train/bicycles/bicycles_0820.jpg
# train/bicycles/bicycles_0821.jpg
# test/bicycles/bicycles_0249.jpg
# train/bicycles/bicycles_0822.jpg
# train/bicycles/bicycles_0823.jpg
# train/bicycles/bicycles_0824.jpg
# train/bicycles/bicycles_0825.jpg
# train/bicycles/bicycles_0826.jpg
# train/bicycles/bicycles_0827.jpg
# test/bicycles/bicycles_0250.jpg
# train/bicycles/bicycles_0828.jpg
# test/bicycles/bicycles_0251.jpg
# train/bicycles/bicycles_0829.jpg
# test/bicycles/bicycles_0252.jpg
# train/bicycles/bicycles_0830.jpg
# test/bicycles/bicycles_0253.jpg
# train/bicycles/bicycles_0831.jpg
# train/bicycles/bicycles_0832.jpg
# train/bicycles/bicycles_0833.jpg
# train/bicycles/bicycles_0834.jpg
# train/bicycles/bicycles_0835.jpg
# train/bicycles/bicycles_0836.jpg
# train/bicycles/bicycles_0837.jpg
# test/bicycles/bicycles_0254.jpg
# train/bicycles/bicycles_0838.jpg
# train/bicycles/bicycles_0839.jpg
# train/bicycles/bicycles_0840.jpg
# train/bicycles/bicycles_0841.jpg
# train/bicycles/bicycles_0842.jpg
# train/bicycles/bicycles_0843.jpg
# train/bicycles/bicycles_0844.jpg
# train/bicycles/bicycles_0845.jpg
# train/bicycles/bicycles_0846.jpg
# train/bicycles/bicycles_0847.jpg
# train/bicycles/bicycles_0848.jpg
# train/bicycles/bicycles_0849.jpg
# train/bicycles/bicycles_0850.jpg
# train/bicycles/bicycles_0851.jpg
# train/bicycles/bicycles_0852.jpg
# train/bicycles/bicycles_0853.jpg
# train/bicycles/bicycles_0854.jpg
# train/bicycles/bicycles_0855.jpg
# test/bicycles/bicycles_0255.jpg
# train/bicycles/bicycles_0856.jpg
# train/bicycles/bicycles_0857.jpg
# train/bicycles/bicycles_0858.jpg
# train/bicycles/bicycles_0859.jpg
# train/bicycles/bicycles_0860.jpg
# train/bicycles/bicycles_0861.jpg
# test/bicycles/bicycles_0256.jpg
# train/bicycles/bicycles_0862.jpg
# test/bicycles/bicycles_0257.jpg
# train/bicycles/bicycles_0863.jpg
# test/bicycles/bicycles_0258.jpg
# test/bicycles/bicycles_0259.jpg
# train/bicycles/bicycles_0864.jpg
# test/bicycles/bicycles_0260.jpg
# train/bicycles/bicycles_0865.jpg
# test/bicycles/bicycles_0261.jpg
# train/bicycles/bicycles_0866.jpg
# train/bicycles/bicycles_0867.jpg
# train/bicycles/bicycles_0868.jpg
# train/bicycles/bicycles_0869.jpg
# train/bicycles/bicycles_0870.jpg
# train/bicycles/bicycles_0871.jpg
# test/bicycles/bicycles_0262.jpg
# train/bicycles/bicycles_0872.jpg
# train/bicycles/bicycles_0873.jpg
# test/bicycles/bicycles_0263.jpg
# test/bicycles/bicycles_0264.jpg
# train/bicycles/bicycles_0874.jpg
# train/bicycles/bicycles_0875.jpg
# train/bicycles/bicycles_0876.jpg
# test/bicycles/bicycles_0265.jpg
# train/bicycles/bicycles_0877.jpg
# train/bicycles/bicycles_0878.jpg
# train/bicycles/bicycles_0879.jpg
# train/bicycles/bicycles_0880.jpg
# test/bicycles/bicycles_0266.jpg
# train/bicycles/bicycles_0881.jpg
# train/bicycles/bicycles_0882.jpg
# train/bicycles/bicycles_0883.jpg
# train/bicycles/bicycles_0884.jpg
# train/bicycles/bicycles_0885.jpg
# train/bicycles/bicycles_0886.jpg
# train/bicycles/bicycles_0887.jpg
# train/bicycles/bicycles_0888.jpg
# train/bicycles/bicycles_0889.jpg
# train/bicycles/bicycles_0890.jpg
# train/bicycles/bicycles_0891.jpg
# train/bicycles/bicycles_0892.jpg
# train/bicycles/bicycles_0893.jpg
# test/bicycles/bicycles_0267.jpg
# test/bicycles/bicycles_0268.jpg
# train/bicycles/bicycles_0894.jpg
# test/bicycles/bicycles_0269.jpg
# test/bicycles/bicycles_0270.jpg
# train/bicycles/bicycles_0895.jpg
# test/bicycles/bicycles_0271.jpg
# train/bicycles/bicycles_0896.jpg
# train/bicycles/bicycles_0897.jpg
# train/bicycles/bicycles_0898.jpg
# train/bicycles/bicycles_0899.jpg
# train/bicycles/bicycles_0900.jpg
# test/bicycles/bicycles_0272.jpg
# train/bicycles/bicycles_0901.jpg
# test/bicycles/bicycles_0273.jpg
# train/bicycles/bicycles_0902.jpg
# train/bicycles/bicycles_0903.jpg
# test/bicycles/bicycles_0274.jpg
# train/bicycles/bicycles_0904.jpg
# train/bicycles/bicycles_0905.jpg
# train/bicycles/bicycles_0906.jpg
# train/bicycles/bicycles_0907.jpg
# train/bicycles/bicycles_0908.jpg
# test/bicycles/bicycles_0275.jpg
# train/bicycles/bicycles_0909.jpg
# train/bicycles/bicycles_0910.jpg
# train/bicycles/bicycles_0911.jpg
# train/bicycles/bicycles_0912.jpg
# train/bicycles/bicycles_0913.jpg
# train/bicycles/bicycles_0914.jpg
# test/bicycles/bicycles_0276.jpg
# train/bicycles/bicycles_0915.jpg
# train/bicycles/bicycles_0916.jpg
# train/bicycles/bicycles_0917.jpg
# train/bicycles/bicycles_0918.jpg
# train/bicycles/bicycles_0919.jpg
# test/bicycles/bicycles_0277.jpg
# train/bicycles/bicycles_0920.jpg
# test/bicycles/bicycles_0278.jpg
# train/bicycles/bicycles_0921.jpg
# test/bicycles/bicycles_0279.jpg
# train/bicycles/bicycles_0922.jpg
# train/bicycles/bicycles_0923.jpg
# train/bicycles/bicycles_0924.jpg
# train/bicycles/bicycles_0925.jpg
# test/bicycles/bicycles_0280.jpg
# train/bicycles/bicycles_0926.jpg
# train/bicycles/bicycles_0927.jpg
# train/bicycles/bicycles_0928.jpg
# train/bicycles/bicycles_0929.jpg
# train/bicycles/bicycles_0930.jpg
# train/bicycles/bicycles_0931.jpg
# train/bicycles/bicycles_0932.jpg
# train/bicycles/bicycles_0933.jpg
# train/bicycles/bicycles_0934.jpg
# train/bicycles/bicycles_0935.jpg
# train/bicycles/bicycles_0936.jpg
# test/bicycles/bicycles_0281.jpg
# test/bicycles/bicycles_0282.jpg
# train/bicycles/bicycles_0937.jpg
# train/bicycles/bicycles_0938.jpg
# train/bicycles/bicycles_0939.jpg
# train/bicycles/bicycles_0940.jpg
# train/bicycles/bicycles_0941.jpg
# train/bicycles/bicycles_0942.jpg
# train/bicycles/bicycles_0943.jpg
# train/bicycles/bicycles_0944.jpg
# test/bicycles/bicycles_0283.jpg
# train/bicycles/bicycles_0945.jpg
# train/bicycles/bicycles_0946.jpg
# test/bicycles/bicycles_0284.jpg
# test/bicycles/bicycles_0285.jpg
# test/bicycles/bicycles_0286.jpg
# train/bicycles/bicycles_0947.jpg
# train/bicycles/bicycles_0948.jpg
# train/bicycles/bicycles_0949.jpg
# train/bicycles/bicycles_0950.jpg
# test/bicycles/bicycles_0287.jpg
# train/bicycles/bicycles_0951.jpg
# train/bicycles/bicycles_0952.jpg
# train/bicycles/bicycles_0953.jpg
# test/bicycles/bicycles_0288.jpg
# test/bicycles/bicycles_0289.jpg
# test/bicycles/bicycles_0290.jpg
# train/bicycles/bicycles_0954.jpg
# train/bicycles/bicycles_0955.jpg
# train/bicycles/bicycles_0956.jpg
# train/bicycles/bicycles_0957.jpg
# test/bicycles/bicycles_0291.jpg
# test/bicycles/bicycles_0292.jpg
# train/bicycles/bicycles_0958.jpg
# train/bicycles/bicycles_0959.jpg
# train/bicycles/bicycles_0960.jpg
# train/bicycles/bicycles_0961.jpg
# train/bicycles/bicycles_0962.jpg
# test/bicycles/bicycles_0293.jpg
# train/bicycles/bicycles_0963.jpg
# train/bicycles/bicycles_0964.jpg
# train/bicycles/bicycles_0965.jpg
# train/bicycles/bicycles_0966.jpg
# train/bicycles/bicycles_0967.jpg
# train/bicycles/bicycles_0968.jpg
# train/bicycles/bicycles_0969.jpg
# train/bicycles/bicycles_0970.jpg
# train/bicycles/bicycles_0971.jpg
# train/bicycles/bicycles_0972.jpg
# train/bicycles/bicycles_0973.jpg
# train/bicycles/bicycles_0974.jpg
# train/bicycles/bicycles_0975.jpg
# test/bicycles/bicycles_0294.jpg
# train/bicycles/bicycles_0976.jpg
# train/bicycles/bicycles_0977.jpg
# test/bicycles/bicycles_0295.jpg
# train/bicycles/bicycles_0978.jpg
# train/bicycles/bicycles_0979.jpg
# train/bicycles/bicycles_0980.jpg
# train/bicycles/bicycles_0981.jpg
# test/bicycles/bicycles_0296.jpg
# train/bicycles/bicycles_0982.jpg
# train/bicycles/bicycles_0983.jpg
# train/bicycles/bicycles_0984.jpg
# train/bicycles/bicycles_0985.jpg
# train/bicycles/bicycles_0986.jpg
# train/bicycles/bicycles_0987.jpg
# train/bicycles/bicycles_0988.jpg
# train/bicycles/bicycles_0989.jpg
# train/bicycles/bicycles_0990.jpg
# train/bicycles/bicycles_0991.jpg
# test/bicycles/bicycles_0297.jpg
# train/bicycles/bicycles_0992.jpg
# train/bicycles/bicycles_0993.jpg
# train/bicycles/bicycles_0994.jpg
# test/bicycles/bicycles_0298.jpg
# train/bicycles/bicycles_0995.jpg
# train/bicycles/bicycles_0996.jpg
# train/bicycles/bicycles_0997.jpg
# train/bicycles/bicycles_0998.jpg
# train/bicycles/bicycles_0999.jpg
# test/bicycles/bicycles_0299.jpg
# train/cars/cars_0000.jpg
# train/cars/cars_0001.jpg
# train/cars/cars_0002.jpg
# train/cars/cars_0003.jpg
# train/cars/cars_0004.jpg
# train/cars/cars_0005.jpg
# test/cars/cars_0000.jpg
# train/cars/cars_0006.jpg
# train/cars/cars_0007.jpg
# train/cars/cars_0008.jpg
# test/cars/cars_0001.jpg
# train/cars/cars_0009.jpg
# train/cars/cars_0010.jpg
# train/cars/cars_0011.jpg
# train/cars/cars_0012.jpg
# train/cars/cars_0013.jpg
# train/cars/cars_0014.jpg
# test/cars/cars_0002.jpg
# train/cars/cars_0015.jpg
# train/cars/cars_0016.jpg
# train/cars/cars_0017.jpg
# train/cars/cars_0018.jpg
# train/cars/cars_0019.jpg
# train/cars/cars_0020.jpg
# train/cars/cars_0021.jpg
# train/cars/cars_0022.jpg
# train/cars/cars_0023.jpg
# train/cars/cars_0024.jpg
# train/cars/cars_0025.jpg
# train/cars/cars_0026.jpg
# test/cars/cars_0003.jpg
# train/cars/cars_0027.jpg
# test/cars/cars_0004.jpg
# train/cars/cars_0028.jpg
# train/cars/cars_0029.jpg
# train/cars/cars_0948.jpg
# test/cars/cars_0284.jpg
# train/cars/cars_0949.jpg
# train/cars/cars_0950.jpg
# train/cars/cars_0951.jpg
# test/cars/cars_0285.jpg
# test/cars/cars_0286.jpg
# train/cars/cars_0952.jpg
# train/cars/cars_0953.jpg
# train/cars/cars_0954.jpg
# train/cars/cars_0955.jpg
# test/cars/cars_0287.jpg
# train/cars/cars_0956.jpg
# train/cars/cars_0957.jpg
# train/cars/cars_0958.jpg
# train/cars/cars_0959.jpg
# train/cars/cars_0960.jpg
# train/cars/cars_0961.jpg
# train/cars/cars_0962.jpg
# test/cars/cars_0288.jpg
# train/cars/cars_0963.jpg
# train/cars/cars_0964.jpg
# train/cars/cars_0965.jpg
# train/cars/cars_0966.jpg
# train/cars/cars_0967.jpg
# train/cars/cars_0968.jpg
# test/cars/cars_0289.jpg
# train/cars/cars_0969.jpg
# train/cars/cars_0970.jpg
# train/cars/cars_0971.jpg
# train/cars/cars_0972.jpg
# train/cars/cars_0973.jpg
# train/cars/cars_0974.jpg
# test/cars/cars_0290.jpg
# train/cars/cars_0975.jpg
# train/cars/cars_0976.jpg
# test/cars/cars_0291.jpg
# test/cars/cars_0292.jpg
# train/cars/cars_0977.jpg
# train/cars/cars_0978.jpg
# train/cars/cars_0979.jpg
# train/cars/cars_0980.jpg
# train/cars/cars_0981.jpg
# train/cars/cars_0982.jpg
# train/cars/cars_0983.jpg
# train/cars/cars_0984.jpg
# test/cars/cars_0293.jpg
# test/cars/cars_0294.jpg
# test/cars/cars_0295.jpg
# train/cars/cars_0985.jpg
# train/cars/cars_0986.jpg
# train/cars/cars_0987.jpg
# train/cars/cars_0988.jpg
# train/cars/cars_0989.jpg
# train/cars/cars_0990.jpg
# train/cars/cars_0991.jpg
# train/cars/cars_0992.jpg
# train/cars/cars_0993.jpg
# test/cars/cars_0296.jpg
# test/cars/cars_0297.jpg
# train/cars/cars_0994.jpg
# test/cars/cars_0298.jpg
# test/cars/cars_0299.jpg
# train/cars/cars_0995.jpg
# train/cars/cars_0996.jpg
# train/cars/cars_0997.jpg
# train/cars/cars_0998.jpg
# train/cars/cars_0999.jpg

# %% [markdown]
# ## Using the DataLoader with ImageFolder
#
# We will now create an `ImageFolder` object, like in the [VGG demo](../Demos/demo_cnn_vgg16.ipynb) of this unit.
# As we did in that demo, we will use a `torchvision.transform` to preprocess the data when training our network.
#
# For this lab, randomly crop a section of between 0.5 and 1 of the original image size, and then resize it to nrow x ncol pixels.
#
# Also, use the following normalization (the default for ImageNet):
#
# `transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) `

# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

batch_size = 10
# TODO
# data_transform = ...
crop = transforms.CenterCrop(64)
data_transform = transforms.Compose(
    [crop, transforms.ToTensor(),transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# TODO
# train_ds = ...
# train_dl = ...

# Create data set using ImageFolder
train_data_dir = './train'
train_ds = ImageFolder(root = train_data_dir, transform=data_transform)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle = True)

# %% [markdown]
# Now, create a `test_dl` object for the test data, using the same data transform as for the training.

# %%
# TODO
# test_ds = ...
# test_dl = ...

# Create test data loader similar to above
test_data_dir = './test'
test_ds = ImageFolder(test_data_dir, transform=data_transform)
test_dl = DataLoader(test_ds, batch_size=batch_size, shuffle = True)

# %% [markdown]
# The following image display function will be useful later.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#### Code from https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html #####
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0)) # rearrange dimensions from (color,y,x) -> (y,x,color)
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean # undo the normalization
    inp = np.clip(inp, 0, 1)
    # Display image, without ticks
    plt.imshow(inp)
    plt.xticks([])
    plt.yticks([])
    if title is not None:
        plt.title(title)

###########################################################################################

# %% [markdown]
# To see how the `train_dl` works, use the `next(iter(train_dl))` method to get a minibatch of data `X,y`.  Display the first 8 images in this mini-batch and label the image with its class label.  You should see that bicycles have `y=0` and cars have `y=1`.

# %%
#Todo
from torchvision.utils import make_grid
X, y = next(iter(train_dl))
for j in range(8):
    plt.figure()
    imshow(X[j])
    plt.title("Label: %d"%y[j])

# %% [markdown]
# ## Loading a Pre-Trained Deep Network
#
# Follow the [VGG16 demo](./vgg16.ipynb) to load a pre-trained VGG16 network.  Rember to set `pretrained=True` in order to also load the pre-trained weights.

# %%
import torch
from torchvision.models import vgg16

# TODO:  Load the VGG16 network
# model = ...
model = vgg16(pretrained = True)

# %% [markdown]
# Now, freeze the parameters of the pretrained model.  To do this, loop over the parameters in the model and set their `requires_grad` flag to `False`. This will stop PyTorch from calculating the gradient for those parameters and stop them from being updated by the optimizer.

# %%
# TODO freeze layers
for param in model.features.parameters():
    param.requires_grad = False

# %% [markdown]
# Remember, from the VGG16 demo, that the network has a `features` portion, with convolutional layers, and a `classifier` portion, with fully connected layers.  We will keeping the features portion but replace the classifier portion.  The idea is that the features portion, which was trained on all of ImageNet, will generate useful features for any image classification task, such as differentiating cars and bikes.
#
# In order to replace the classifier portion, we first need to find the size of the input to the classifier portion of the network, so that we can build our own with the proper size.  You can do this using

# %%
print(model.classifier[0])
# Out:
# Linear(in_features=25088, out_features=4096, bias=True)

# %% [markdown]
# Replace `model.classifier` with a neural network consisting of the following layers:
# * Linear w/ 256 output channels
# * ReLU
# * Dropout w/ p = 0.5
# * Linear w/ 1 output channel (indicating car vs bike)
# * Sigmoid
#
# This network can be constructed using 1 line via `nn.Sequential`, like in [demo_cnn_autoencoder](../Demos/demo_cnn_autoencoder.ipynb).

# %%
import torch.nn as nn

# TODO Replace the classifier part of the network
# model.classifier = ...
model.classifier = nn.Sequential(nn.Linear(25088,256),nn.ReLU(),nn.Dropout(p=0.5),nn.Linear(256,1),nn.Sigmoid())

# %% [markdown]
# Now we will print a summary of the model.
# Confirm that it includes a features portion and a classifier portion, each constructed by a Sequential() object.
# The features portion should be the same as the VGG network, and the classifier portion should consist of the following sequence of Modules: Linear, Relu, Dropout, Linear, Sigmoid.

# %%
print(str(model))
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=1, bias=True)
#     (4): Sigmoid()
#   )
# )

# %% [markdown]
# ## Train the Model
#
# Select the correct loss function and an optimizer to train the model. Remember that we are doing *binary* classification.

# %%
import torch.optim as optim

lr = 1e-3

# TODO
# criterion = ...
# opt = ...
criterion = nn.BCELoss()
opt = optim.Adam(model.parameters(), lr = lr, weight_decay = 0.005)

# %% [markdown]
# Now, run the training.  If you are using a CPU on a regular laptop, each epoch should take about 1-4 minutes, so you should be able to finish 5 epochs or so within 5-20 minutes.  On a reasonable GPU, even with 150 x 150 images, it should take about 10 seconds per epoch.  If you use `(nrow,ncol) = (64,64)` images, you should get about 90-95% accuracy after 5 epochs.

# %%
# TODO
num_epoch = 5

a_tr_loss = np.zeros([num_epoch])
a_tr_accuracy = np.zeros([num_epoch])
a_ts_loss = np.zeros([num_epoch])
a_ts_accuracy = np.zeros([num_epoch])

for epoch in range(num_epoch):

    model.train() # put model in training mode
    correct = 0 # initialize error counter
    total = 0 # initialize total counter
    batch_loss_tr = []
    # iterate over training set
    for train_iter, data in enumerate(train_dl):
        x_batch,y_batch = data
        #y_batch = y_batch.type(torch.long)
        out = model(x_batch)
        # Compute Loss
        loss = criterion(out,y_batch.float())
        batch_loss_tr.append(loss.item())
        # Compute gradients using back propagation
        opt.zero_grad()
        loss.backward()
        # Take an optimization 'step'
        opt.step()
        # Do hard classification: index of largest score
        predicted = torch.transpose(out.round(),1,0)
        # Compute number of decision errors
        total += y_batch.size(0)
        correct += (predicted == y_batch).sum().item()
        
    a_tr_loss[epoch] = np.mean(batch_loss_tr) # Compute average loss over epoch
    a_tr_accuracy[epoch] = 100*correct/total

    model.eval() # put model in evaluation mode
    correct = 0 # initialize error counter
    total = 0 # initialize total counter
    batch_loss_ts = []
    with torch.no_grad():
        for data in test_dl:
            images, labels = data
            labels = labels.type(torch.float)
            outputs = model(images)
            batch_loss_ts.append(criterion(outputs,labels).item())
            predicted = torch.transpose(outputs.round(),1,0)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
    a_ts_loss[epoch] = np.mean(batch_loss_ts)
    a_ts_accuracy[epoch] = 100*correct/total
    # Print details every print_mod epoch
    print('Epoch: {0:2d}   Train Loss: {1:.3f}   '.format(epoch+1, a_tr_loss[epoch])
          +'Train Accuracy: {0:.2f}    Test Loss: {1:.3f}   '.format(a_tr_accuracy[epoch], a_ts_loss[epoch])
          +'Test Accuracy: {0:.2f}'.format(a_ts_accuracy[epoch]))
# Out:
# D:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:498: UserWarning: Using a target size (torch.Size([10])) that is different to the input size (torch.Size([10, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# Epoch:  1   Train Loss: 0.695   Train Accuracy: 92.90    Test Loss: 0.456   Test Accuracy: 96.67
# Epoch:  2   Train Loss: 0.362   Train Accuracy: 96.60    Test Loss: 0.288   Test Accuracy: 96.33
# Epoch:  3   Train Loss: 0.177   Train Accuracy: 96.50    Test Loss: 0.218   Test Accuracy: 96.67
# Epoch:  4   Train Loss: 0.131   Train Accuracy: 97.40    Test Loss: 0.187   Test Accuracy: 95.83
# Epoch:  5   Train Loss: 0.126   Train Accuracy: 97.20    Test Loss: 0.198   Test Accuracy: 96.17

# %% [markdown]
# Finally, show some example test images with their predicted and actual labels in the title.

# %%
from random import randrange
import pandas as pd
from torchvision.utils import save_image
import scipy as sp
n_show = 8
# TODO
images = []
for k in range(n_show):
    X, y = next(iter(test_dl))
    plt.figure()
    a = randrange(1,9,1)
    y_hat = model(X)
    imshow(X[a])
    plt.title("Predicted label: %d, actual label: %d"%(y_hat[a],y[a]))
